# %%
def areas(larg, comp):
  a = larg * comp
  print(f'Um terreno com as medidas {larg} m x {comp} m é {a} m².')


l = float(input('Digite a largura: '))
c = float(input('Digite o comprimento: '))
areas(l, c)
# Out:
# Digite a largura: 5
# Digite o comprimento: 8.5
# Um terreno com as medidas 5.0 m x 8.5 m é 42.5 m².
