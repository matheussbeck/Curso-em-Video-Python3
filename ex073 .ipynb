# %%
tabela = ('Athletico-PR','Bahia','Flamengo','Botafogo','São Paulo','Cruzeiro','Atlético-MG','Bragantino','Palmeiras','Internacional','Fortaleza','Grêmio','Vasco da Gama','Criciúma','Juventude','Corinthians','Fluminense','EC Vitória','Atlético-GO','Cuiabá')
print(f'Os cinco primeiros são {tabela[0:5]}')
print(f'Os quatro ultimos são {tabela[-4:]}')
print(f'Times em ordem alfabética: {sorted(tabela)}')
print(f'O Bahia está na {tabela.index("Bahia")+1}º posição')
# Out:
# Os cinco primeiros são ('Athletico-PR', 'Bahia', 'Flamengo', 'Botafogo', 'São Paulo')
# Os quatro ultimos são ('Fluminense', 'EC Vitória', 'Atlético-GO', 'Cuiabá')
# Times em ordem alfabética: ['Athletico-PR', 'Atlético-GO', 'Atlético-MG', 'Bahia', 'Botafogo', 'Bragantino', 'Corinthians', 'Criciúma', 'Cruzeiro', 'Cuiabá', 'EC Vitória', 'Flamengo', 'Fluminense', 'Fortaleza', 'Grêmio', 'Internacional', 'Juventude', 'Palmeiras', 'São Paulo', 'Vasco da Gama']
# O Bahia está na 2º posição
