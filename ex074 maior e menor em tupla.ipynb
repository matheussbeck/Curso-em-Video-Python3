# %%
from random import randint

seq = (randint(1,10),randint(1,10),randint(1,10),randint(1,10),randint(1,10),)
print (f'Eu sorteei os valores {seq}')
print (f'O maior foi {max(seq)} e o menor foi {min(seq)}')
# Out:
# Eu sorteei os valores (9, 3, 1, 10, 10)
# O maior foi 10 e o menor foi 1
