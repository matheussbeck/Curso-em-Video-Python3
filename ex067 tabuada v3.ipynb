# %%
n= c = 0
while True:
  n = int(input('Digite a Tabuada desejada: '))
  print('-=-'*30)
  if n < 0:
    break
  for c in range(1,11):
    print(f'{n} x {c} = {n*c}')
    c += 1
  print('-=-'*30)
print('Programa Encerrado !')
# Out:
# Digite a Tabuada desejada: 15
# -=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=-
# 15 x 1 = 15
# 15 x 2 = 30
# 15 x 3 = 45
# 15 x 4 = 60
# 15 x 5 = 75
# 15 x 6 = 90
# 15 x 7 = 105
# 15 x 8 = 120
# 15 x 9 = 135
# 15 x 10 = 150
# -=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=-
# Digite a Tabuada desejada: 25
# -=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=-
# 25 x 1 = 25
# 25 x 2 = 50
# 25 x 3 = 75
# 25 x 4 = 100
# 25 x 5 = 125
# 25 x 6 = 150
# 25 x 7 = 175
# 25 x 8 = 200
# 25 x 9 = 225
# 25 x 10 = 250
# -=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=-
# Digite a Tabuada desejada: -5
# -=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=-
# Programa Encerrado !
