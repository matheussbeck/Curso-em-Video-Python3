# %%
lista = (int(input('Digite um número: ')),int(input('Digite um número: ')),int(input('Digite um número: ')),int(input('Digite um número: ')))
print (f'Você digitou os números {lista}')
print(f'O valor 9 apareceu {lista.count(9)} vezes')
print(f'O valor 3 apareceu {lista.index(3)+1}ª posição')
# Out:
# Digite um número: 9
# Digite um número: 2
# Digite um número: 5
# Digite um número: 7
# Você digitou os números (9, 2, 5, 7)
# O valor 9 apareceu 1 vezes
