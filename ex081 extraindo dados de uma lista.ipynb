# %%
valores = []
r = ''
while True:
  n = int(input('Digite um valor: '))
  lista.append(n)
  r = str(input('Deseja continuar? [S/N] ')).strip().upper()[0]
  if r in 'Nn':
    break
lista.sort(reverse=True)
print(lista)
print(f'Você digitou {len(lista)} valores')
if 5 in lista:
  print('O 5 está na lista')
else:
  print('O 5 não esta na lista')
# Out:
# Digite um valor: 8
# Deseja continuar? [S/N] s
# Digite um valor: 9
# Deseja continuar? [S/N] s
# Digite um valor: 1
# Deseja continuar? [S/N] s
# Digite um valor: 45
# Deseja continuar? [S/N] s
# Digite um valor: 2
# Deseja continuar? [S/N] n
# [45, 12, 12, 12, 9, 9, 9, 9, 9, 8, 8, 8, 8, 8, 7, 6, 5, 5, 5, 5, 3, 2, 2, 2, 1, 1, 1]
# Você digitou 27 valores
# O 5 está na lista
